# %% [markdown]
# # University of Stirling
#
# # ITNPBD2 Representing and Manipulating Data
#
# # Assignment Autumn 2023
#
# # A Consultancy Job for JC Penney
#
# This notebook forms the assignment instructions and submission document of the assignment for ITNPBD2. Read the instructions carefully and enter code into the cells as indicated.
#
# You will need these five files, which were in the Zip file you downloaded from the course webpage:
#
# - jcpenney_reviewers.json
# - jcpenney_products.json
# - products.csv
# - reviews.csv
# - users.csv
#
# The data in these files describes products that have been sold by the American retail giant, JC Penney, and reviews by customers who bought them. Note that the product data is real, but the customer data is synthetic.
#
# Your job is to process the data, as requested in the instructions in the markdown cells in this notebook.

# %% [markdown]
# # Completing the Assignment
#
# Rename this file to be xxxxxx_BD2 where xxxxxx is your student number, then type your code and narrative description into the boxes provided. Add as many code and markdown cells as you need. The cells should contain:
#
# - **Text narrative describing what you did with the data**
# - **The code that performs the task you have described**
# - **Comments that explain your code**

# %% [markdown]
# # Marking Scheme
# The assessment will be marked against the university Common Marking Scheme (CMS)
#
# Here is a summary of what you need to achieve to gain a grade in the major grade bands:
#
# |Grade|Requirement|
# |:---|:---|
# | Fail | You will fail if your code does not run or does not achieve even the basics of the task. You may also fail if you submit code without either comments or a text explanation of what the code does.|
# | Pass | To pass, you must submit sufficient working code to show that you have mastered the basics of the task, even if not everything works completely. You must include some justifications for your choice of methods, but without mentioning alternatives. |
# | Merit | For a merit, your code must be mostly correct, with only small problems or parts missing, and your comments must be useful rather than simply re-stating the code in English. Most choices for methods and structures should be explained and alternatives mentioned. |
# | Distinction | For a distinction, your code must be working, correct, and well commented and shows an appreciation of style, efficiency and reliability. All choices for methods and structures are concisely justified and alternatives are given well thought considerations. For a distinction, your work should be good enough to present to executives at the company.|
#
# The full details of the CMS can be found here
#
# https://www.stir.ac.uk/about/professional-services/student-academic-and-corporate-services/academic-registry/academic-policy-and-practice/quality-handbook/assessment-policy-and-procedure/appendix-2-postgraduate-common-marking-scheme/
#
# Note that this means there are not certain numbers of marks allocated to each stage of the assignment. Your grade will reflect how well your solutions and comments demonstrate that you have achieved the learning outcomes of the task.

# %% [markdown]
# ## Submission
# When you are ready to submit, **print** your notebook as PDF (go to File -> Print Preview) in the Jupyter menu. Make sure you have run all the cells and that their output is displayed. Any lines of code or comments that are not visible in the pdf should be broken across several lines. You can then submit the file online.
#
# Late penalties will apply at a rate of three marks per day, up to a maximum of 7 days. After 7 days you will be given a mark of 0. Extensions will be considered under acceptable circumstances outside your control.
#
# ## Academic Integrity
#
# This is an individual assignment, and so all submitted work must be fully your own work.
#
# The University of Stirling is committed to protecting the quality and standards of its awards. Consequently, the University seeks to promote and nurture academic integrity, support staff academic integrity, and support students to understand and develop good academic skills that facilitate academic integrity.
#
# In addition, the University deals decisively with all forms of Academic Misconduct.
#
# Where a student does not act with academic integrity, their work or behaviour may demonstrate Poor Academic Practice or it may represent Academic Misconduct.
#
# ### Poor Academic Practice
#
# Poor Academic Practice is defined as: "The submission of any type of assessment with a lack of referencing or inadequate referencing which does not effectively acknowledge the origin of words, ideas, images, tables, diagrams, maps, code, sound and any other sources used in the assessment."
#
# ### Academic Misconduct
#
# Academic Misconduct is defined as: "any act or attempted act that does not demonstrate academic integrity and that may result in creating an unfair academic advantage for you or another person, or an academic disadvantage for any other member or member of the academic community."
#
# Plagiarism is presenting somebody else’s work as your own **and includes the use of artificial intelligence tools such as GPT or CoPilot**. Plagiarism is a form of academic misconduct and is taken very seriously by the University. Students found to have plagiarised work can have marks deducted and, in serious cases, even be expelled from the University. Do not submit any work that is not entirely your own. Do not collaborate with or get help from anybody else with this assignment.
#
# The University of Stirling's full policy on Academic Integrity can be found at:
#
# https://www.stir.ac.uk/about/professional-services/student-academic-and-corporate-services/academic-registry/academic-policy-and-practice/quality-handbook/academic-integrity-policy-and-academic-misconduct-procedure/

# %% [markdown]
# ## The Assignment
# Your task with this assignment is to use the data provided to demonstrate your Python data manipulation skills.
#
# There are three `.csv` files and two `.json` files so you can process different types of data. The files also contain unstructured data in the form of natural language in English and links to images that you can access from the JC Penney website (use the field called `product_image_urls`).
#
# Start with easy tasks to show you can read in a file, create some variables and data structures, and manipulate their contents. Then move onto something more interesting.
#
# Look at the data that we provided with this assessment and think of something interesting to do with it using whatever libraries you like. Describe what you decide to do with the data and why it might be interesting or useful to the company to do it.
#
# You can add additional data if you need to - either download it or access it using `requests`. Produce working code to implement your ideas in as many cells as you need below. There is no single right answer, the aim is to simply show you are competent in using python for data analysis. Exactly how you do that is up to you.
#
# For a distinction class grade, this must show originality, creative thinking, and insights beyond what you've been taught directly on the module.

# %% [markdown]
# ## Structure
# You may structure the project how you wish, but here is a suggested guideline to help you organise your work:
#
#  1. Data Exploration - Explore the data and show you understand its structure and relations
#  2. Data Validation - Check the quality of the data. Is it complete? Are there obvious errors?
#  3. Data Visualisation - Gain an overall understanding of the data with visualisations
#  4. Data Analysis = Set some questions and use the data to answer them
#  5. Data Augmentation - Add new data from another source to bring new insights to the data you already have

# %% [markdown]
# # Remember to make sure you are working completely on your own.
# # Don't work in a group or with a friend
# You may NOT use any automated code generation or analytics tools for this assignment, so do not use tools like GPT. You can look up the syntax for the functions you use, but you must write the code yourself and the comments must provide an insightful analysis of the results.

# %%
# Put your code and comments in cells below here
# Add as many cells as you need

# %% [markdown]
# # GENERAL OBJECTIVE

# %% [markdown]
# Describe through the exploration of the data provided in the five files, both of them .json, and three .csv extension, the variable products that have been sold by the American retail giant, JC Penney, and also other focus are the customers with one important variable called reviews, according the comments that have made the customers when bought them the products.

# %% [markdown]
# # Specific Objectives:

# %% [markdown]
# 1. Explore the files: jcpenney_reviewers.json, jcpenney_products.json, products.csv, reviews.csv, users.csv, to understand the behaviour of all the columns (variables).
# 2. Analyze the rating that users have about the products, classified by Age Group and State.
# 3. Choose one of the most popular states in terms of fashion (New York) and analyze the brand that is in the top ten (use its image with augmented data).
# 4. Analyze the perception (sentiments) that customers have towards the products.

# %% [markdown]
# # 1. DATA EXPLORATION

# %% [markdown]
# First, the exploration of the data provided begins with the use of the librarys that allow us to open the files and also to make an exploration of the data: *pandas* and *numpy*, which will allow us:
# 1. To make an analysis of the data,
# 2. To process and manipulate the arrays(containers which are able to store more than one item at the same time).
# Let's see the code below:

# %%
#Import the library pandas and numpy:
import pandas as pd
import numpy as np

# %% [markdown]
# # 1.1 Exploration .json files:

# %% [markdown]
# **1.1.1 JCPenney - Products**:

# %%
#Read with pandas the file products with the .read_json function and store in the object prod_json:
path='C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/jcpenney_products.json'
prod_json= pd.read_json(path, lines=True)

# %%
#Read the first lines of the file products with .head():
prod_json.head()
print(prod_json.head())
# Out:
#                             uniq_id           sku  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
#
#                                     name_title  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          description list_price sale_price  \
# 0  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 1  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# 2  You'll return to our Alfred Dunner pull-on cap...      41.09      24.16
# ...

# %%
#Check all the .columns in the dataframe prod_json:
prod_json.columns
# Out:
# Index(['uniq_id', 'sku', 'name_title', 'description', 'list_price',
#        'sale_price', 'category', 'category_tree', 'average_product_rating',
#        'product_url', 'product_image_urls', 'brand', 'total_number_reviews',
#        'Reviews', 'Bought With'],
#       dtype='object')

# %%
#Explore the info of the prod_json file with .info():
prod_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7982 entries, 0 to 7981
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   uniq_id                 7982 non-null   object
#  1   sku                     7982 non-null   object
#  2   name_title              7982 non-null   object
#  3   description             7982 non-null   object
#  4   list_price              7982 non-null   object
#  5   sale_price              7982 non-null   object
#  6   category                7982 non-null   object
#  7   category_tree           7982 non-null   object
#  8   average_product_rating  7982 non-null   float64
#  9   product_url             7982 non-null   object
#  10  product_image_urls      7982 non-null   object
#  11  brand                   7982 non-null   object
#  12  total_number_reviews    7982 non-null   int64
#  13  Reviews                 7982 non-null   object
# ...

# %% [markdown]
# The prod_json object has 15 columns, which from now on we will call *variables*, one of it is the index of the product, called *uniq_id* (key variable), the type of the file is a dataframe, with 7982 observations. We will pay special attention to this key variable, which will later be used to link with other dataframes.
# There are three columns with numerical values: list_price, sale_price and total_number_reviews, however just the last one is type integer.
#
# Let's continue exploring.

# %%
#Group by the variable brand using the function .describe and .groupby, sorted by descendig order:
display(prod_json.brand.describe())
#Show the 10 first rows:
prod_json.groupby("brand").brand.count().sort_values(ascending=False).head(10)
# Out:
# count        7982
# unique        721
# top       ARIZONA
# freq          413
# Name: brand, dtype: object
# brand
# ARIZONA                 413
# LIZ CLAIBORNE           388
# Asstd National Brand    294
# Xersion                 256
# STAFFORD                231
# St. John's Bay          220
# WORTHINGTON             211
# A.N.A                   191
# Nike                    180
# STYLUS                  166
# Name: brand, dtype: int64

# %% [markdown]
# We have 721 unique brands in the dataframe prod_json corresponding at 7982 products, one of the most important brand is *ARIZONA* with a frequency of 413 sold products, followed by LIZ CLAIBORNE, and Asstd National Brand. Now we are going to check the variable category.

# %%
#Group by the variable category:
display(prod_json.category.describe())
prod_json.groupby("category").category.count().sort_values(ascending=False).head(10)
# Out:
# count     7982
# unique    1169
# top
# freq       636
# Name: category, dtype: object
# category
#                        636
# view all               376
# sale                   343
# view all brands        285
# clearance              166
# pants                  141
# outfits you'll love    108
# jeans                  100
# tops                    78
# shorts                  72
# Name: category, dtype: int64

# %% [markdown]
# We have between the brands, 1169 unique categorys, but also we can see that the most highest frequency of the categorys is with null data, which correspond at 636, that in relative terms is around 54% of the unique categories.

# %%
#To group by the variable category_tree:
display(prod_json.category_tree.describe())
prod_json.groupby("category_tree").category_tree.count().sort_values(ascending=False).head(10)
# Out:
# count     7982
# unique    1997
# top
# freq       636
# Name: category_tree, dtype: object
# category_tree
#                                 636
# jcpenney|view all               212
# jcpenney|view all brands        198
# jcpenney|sale                   197
# jcpenney|women|view all         102
# jcpenney|pants                   92
# jcpenney|clearance               74
# jcpenney|outfits you'll love     59
# jcpenney|jeans                   59
# jcpenney|tops                    44
# Name: category_tree, dtype: int64

# %% [markdown]
# We can see that in the top of category tree in the sixth place are pants, followed by clearance, and outfits. At the end of the top ten are the categories jeans and tops.

# %% [markdown]
# We need to get more information through the linking between dataframes, for this reason let's go to create an index into the dataframe prod_json, called *uniq_id*.

# %%
#To create as index the uniq_id column, using the function .reset_index(), and then .set_index():
prod_json=prod_json.reset_index().set_index("uniq_id")
print(prod_json.head())
# Out:
#                                   index           sku  \
# uniq_id
# b6c0b6bea69c722939585baeac73c13d      0  pp5006380337
# 93e5272c51d8cce02597e3ce67b7ad0a      1  pp5006380337
# 013e320f2f2ec0cf5b3ff5418d688528      2  pp5006380337
# 505e6633d81f2cb7400c0cfa0394c427      3  pp5006380337
# d969a8542122e1331e304b09f81a83f6      4  pp5006380337
#
#                                                                    name_title  \
# uniq_id
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
# 93e5272c51d8cce02597e3ce67b7ad0a  Alfred Dunner® Essential Pull On Capri Pant
# 013e320f2f2ec0cf5b3ff5418d688528  Alfred Dunner® Essential Pull On Capri Pant
# 505e6633d81f2cb7400c0cfa0394c427  Alfred Dunner® Essential Pull On Capri Pant
# d969a8542122e1331e304b09f81a83f6  Alfred Dunner® Essential Pull On Capri Pant
#
#                                                                         description  \
# uniq_id
# ...

# %% [markdown]
# Now we have our prod_json dataframe with an unique identity number, *uniq_id*.

# %% [markdown]
# Let's go now to check the json file *reviewers*, we are going to read line by line using the library pandas:

# %% [markdown]
# **1.1.2 JCPenney - Reviewers**:

# %%
#To read with pandas the json file reviewers with the function .read_json:
path1='C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/jcpenney_reviewers.json'
rev_json= pd.read_json(path1, lines=True)

# %% [markdown]
# Now we are going to check the first 10 lines of the file:

# %%
#Read the first lines of the file reviewers with .head():
rev_json.head()
# Out:
#    Username         DOB          State  \
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts
# 2  eehe1434  08.08.1950          Idaho
# 3  hkxj1334  03.08.1969        Florida
# 4  jjbd1412  26.07.2001        Georgia
#
#                                             Reviewed
# 0                 [cea76118f6a9110a893de2b7654319c0]
# 1                 [fa04fe6c0dd5189f54fe600838da43d3]
# 2                                                 []
# 3  [f129b1803f447c2b1ce43508fb822810, 3b0c9bc0be6...
# 4                                                 []

# %% [markdown]
# Although at simple sight it seems that the file *reviewers* has 4 columns, we are going to look at the information with the function .info(), as you can see below:

# %%
#Look at the information into the reviewers file:
rev_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Username  5000 non-null   object
#  1   DOB       5000 non-null   object
#  2   State     5000 non-null   object
#  3   Reviewed  5000 non-null   object
# dtypes: object(4)
# memory usage: 156.4+ KB

# %% [markdown]
# The file has 4 columns as predicted, which from now on we will call variables. The file has a total of 5000 observations, with no null data, one of the columns seems as it could be a uniq ID of the users *Username*, and also there is more personal information of the users such as, the date of birth *DOB*, and a categorical variable called *State*, which explain the location of the customers.

# %% [markdown]
# Now let's review the information in more depth.

# %%
#Look of the names of columns in reviewers:
rev_json.columns
# Out:
# Index(['Username', 'DOB', 'State', 'Reviewed'], dtype='object')

# %% [markdown]
# As we can see in the json file *reviewers*, the DOB variable is in a format that is not a date type(YYYY-MM-DD), therefore we are going to debug this variable using the function *to_datetime*:

# %%
#To change the format of the variable DOB into user object:
#Use the function to_datetime to calculate the difference between date of time:
rev_json["DOB"]=pd.to_datetime(rev_json["DOB"],format="%d.%m.%Y")
rev_json.head()
# Out:
#    Username        DOB          State  \
# 0  bkpn1412 1983-07-31         Oregon
# 1  gqjs4414 1998-07-27  Massachusetts
# 2  eehe1434 1950-08-08          Idaho
# 3  hkxj1334 1969-08-03        Florida
# 4  jjbd1412 2001-07-26        Georgia
#
#                                             Reviewed
# 0                 [cea76118f6a9110a893de2b7654319c0]
# 1                 [fa04fe6c0dd5189f54fe600838da43d3]
# 2                                                 []
# 3  [f129b1803f447c2b1ce43508fb822810, 3b0c9bc0be6...
# 4                                                 []

# %% [markdown]
# Now we can see that the file is taking better shape.

# %% [markdown]
# It is very important that to strengthen the analysis we can create key variables to allow us linked between the dataframes, therefore we are going to create an unique identity number, creating an index with the variable *Username*:

# %%
#To create as index with the Username:
rev_json=rev_json.reset_index().set_index("Username")
display(rev_json.head())
# Out:
#           index        DOB          State  \
# Username
# bkpn1412      0 1983-07-31         Oregon
# gqjs4414      1 1998-07-27  Massachusetts
# eehe1434      2 1950-08-08          Idaho
# hkxj1334      3 1969-08-03        Florida
# jjbd1412      4 2001-07-26        Georgia
#
#                                                    Reviewed
# Username
# bkpn1412                 [cea76118f6a9110a893de2b7654319c0]
# gqjs4414                 [fa04fe6c0dd5189f54fe600838da43d3]
# eehe1434                                                 []
# hkxj1334  [f129b1803f447c2b1ce43508fb822810, 3b0c9bc0be6...
# jjbd1412                                                 []

# %% [markdown]
# Now that we have explored the json type files and have a clear idea of how to use them, we are going to make a pause with these files that will be useful to us later. Now we are going to explore the csv type files.

# %% [markdown]
# # 1.2 Exploration  .csv files:

# %% [markdown]
# First, we are going to begin with the *users* file. We are going to open line by line with the use of pandas:

# %% [markdown]
# **1.2.1 Users:**

# %%
#To read the file .csv users with the .read_csv():
user=pd.read_csv("C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/users.csv")
user.head()
# Out:
#    Username         DOB          State
# 0  bkpn1412  31.07.1983         Oregon
# 1  gqjs4414  27.07.1998  Massachusetts
# 2  eehe1434  08.08.1950          Idaho
# 3  hkxj1334  03.08.1969        Florida
# 4  jjbd1412  26.07.2001        Georgia

# %% [markdown]
# At simple sight this file has three columns, one seems to be the unique identity number of the users called *Username*, the variable DOB - date of birth- give us more personal information of the users, and finally the categorical variable State.

# %% [markdown]
# Now we are going to look what are the names of the columns, to identify if there is any similar information to compare with the other files.

# %%
#To look the names of columns:
user.columns
# Out:
# Index(['Username', 'DOB', 'State'], dtype='object')

# %% [markdown]
# In this file we can check that also as in the other json file of the users, the variable *DOB* is not in the correct format (YYYY-MM-DD). Let's to put in the correct format, using the function *to_datetime*:

# %%
#To change the format of the variable DOB into user object:
user["DOB"]=pd.to_datetime(user["DOB"],format="%d.%m.%Y")
user.head()
# Out:
#    Username        DOB          State
# 0  bkpn1412 1983-07-31         Oregon
# 1  gqjs4414 1998-07-27  Massachusetts
# 2  eehe1434 1950-08-08          Idaho
# 3  hkxj1334 1969-08-03        Florida
# 4  jjbd1412 2001-07-26        Georgia

# %% [markdown]
# We can see that will be interesting to check more in depth what is the frequency of the categorical variable *State*, it will allow the function *groupby*, and also we are going to check in a descending order the top ten States. Here we go:

# %%
#To group by the categorical variable State:
display(user.State.describe())
user.groupby("State").State.count().sort_values(ascending=False).head(10)
# Out:
# count              5000
# unique               57
# top       Massachusetts
# freq                107
# Name: State, dtype: object
# State
# Massachusetts               107
# Delaware                    106
# Vermont                     103
# Northern Mariana Islands    102
# New Jersey                  101
# Oklahoma                    100
# California                   99
# Kentucky                     99
# Montana                      97
# Oregon                       96
# Name: State, dtype: int64

# %% [markdown]
# We can see that for the case of the users, the most of them are from the State of *Massachusetts* from a total of 57 unique States. We have 5000 observations (users) in our file. The last country of the top ten is *Oregon*.

# %% [markdown]
# Now that we have the DOB depured in this file will be interesting to create through this variable a new variable called *Age* of the users, to do this we are going to import the single module *datetime*. For the calculation we will use the current date. Let's do it.

# %%
#Calculate the age using the variable date of birth - DOB in the file.
#Import datetime function:
from datetime import datetime
#We use the current day:
current_date = datetime.now()
#Then create into the data frame a new variable called Age:
user["Age"] = (current_date - user["DOB"]).astype('<m8[Y]')

#Display the data frame with the new 'Age' column:
print(user)
# Out:
#       Username        DOB          State   Age
# 0     bkpn1412 1983-07-31         Oregon  40.0
# 1     gqjs4414 1998-07-27  Massachusetts  25.0
# 2     eehe1434 1950-08-08          Idaho  73.0
# 3     hkxj1334 1969-08-03        Florida  54.0
# 4     jjbd1412 2001-07-26        Georgia  22.0
# ...        ...        ...            ...   ...
# 4995  mfnn1212 1997-07-27       Delaware  26.0
# 4996  ejnb3414 1976-08-01      Minnesota  47.0
# 4997  pdzw1433 1994-07-28           Ohio  29.0
# 4998  npha1342 1953-08-07        Montana  70.0
# 4999  yuoc2324 1975-08-02   South Dakota  48.0
#
# [5000 rows x 4 columns]

# %% [markdown]
# We can see that now our dataframe has 4 columns with the new variable *Age*.

# %% [markdown]
# Let's continue with the exploration of the products.csv file line by line, using the library pandas:

# %% [markdown]
# **1.2.2 Products:**

# %%
#Read the file products:
prod=pd.read_csv("C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/products.csv")
prod.head()
# Out:
#                             Uniq_id           SKU  \
# 0  b6c0b6bea69c722939585baeac73c13d  pp5006380337
# 1  93e5272c51d8cce02597e3ce67b7ad0a  pp5006380337
# 2  013e320f2f2ec0cf5b3ff5418d688528  pp5006380337
# 3  505e6633d81f2cb7400c0cfa0394c427  pp5006380337
# 4  d969a8542122e1331e304b09f81a83f6  pp5006380337
#
#                                           Name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          Description  Price  Av_Score
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09     3.000
# 2  Youll return to our Alfred Dunner pull-on capr...  41.09     2.625
# 3  Youll return to our Alfred Dunner pull-on capr...  41.09     3.500
# ...

# %% [markdown]
# We are going to check the information in more depth into the products file:

# %%
#To check the info into products:
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7982 entries, 0 to 7981
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Uniq_id      7982 non-null   object
#  1   SKU          7915 non-null   object
#  2   Name         7982 non-null   object
#  3   Description  7439 non-null   object
#  4   Price        5816 non-null   float64
#  5   Av_Score     7982 non-null   float64
# dtypes: float64(2), object(4)
# memory usage: 374.3+ KB

# %% [markdown]
# There are 7982 observations with 6 columns, which from now on we will call them variables, aparently there is no null data in each one. Two of the variables are type float, the *Price* and the *Av_Score*. However if we see the total count of the data for every column is different, specially by the Price, it gives the suspicion that there are NA values into this variable. Let's check:

# %% [markdown]
# Now we are going to review the statistical descriptive measures of the variable:*Price*, using the function describe:

# %%
#To get statistical descriptive measures of the price using describe:
#Now we are going to check some descriptive measures of the price:
price_stat=prod["Price"].describe()
price_stat
# Out:
# count     5816.000000
# mean       144.776618
# std        499.223719
# min        -65.270000
# 25%         40.700000
# 50%         58.010000
# 75%         87.020000
# max      17122.170000
# Name: Price, dtype: float64

# %% [markdown]
# We can check that there is interesting information, there is a maximum value of 17122.17 which is too much far from the mean and also from the standard deviation, it could be consider an outlier. Also, there is a minimum negative value of -65.27. Later in the section of Visualization I will show a scatter diagram to review how the price behaves.

# %% [markdown]
# Also, we can compare that the internal mean() function of pandas automatically ignore NaN values. According the reference: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.mean.html, *(...)the only scenario well you get NaN, is when NaN is the only value, then, the mean value of an empty set, gives NaN(...).

# %% [markdown]
# The variable Av_Score is also interesting into the analysis, I am going to show the behaviour of the variable with the function describe:

# %%
#To check some descriptive measures of the Av_Score:
av_score_stat=prod["Av_Score"].describe()
av_score_stat
# Out:
# count    7982.000000
# mean        2.988683
# std         0.911673
# min         1.000000
# 25%         2.500000
# 50%         3.000000
# 75%         3.500000
# max         5.000000
# Name: Av_Score, dtype: float64

# %% [markdown]
# The average score shows that the average is closer to 3, the maximun score is 5 and at least the 75% of the products have an average score of 3.5. The half of the products have an average score of 3, but the minimum score is 1. It gives more information of the products, the average of reputation of the products is in the half of the maximum score.

# %% [markdown]
# Finally, we are going to open the last csv file called *reviews* to know what more information we can use for our analysis.

# %% [markdown]
# **1.2.3 Reviews:**

# %%
#To read the file reviews:
rev=pd.read_csv("C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/reviews.csv")
rev.head()
# Out:
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
#
#                                               Review
# 0  You never have to worry about the fit...Alfred...
# 1  Good quality fabric. Perfect fit. Washed very ...
# 2  I do not normally wear pants or capris that ha...
# 3  I love these capris! They fit true to size and...
# 4  This product is very comfortable and the fabri...

# %% [markdown]
# Let's take a look of the information into the *reviews* csv file:

# %%
#To check the info in the dataframe reviews:
rev.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39063 entries, 0 to 39062
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Uniq_id   39063 non-null  object
#  1   Username  39063 non-null  object
#  2   Score     39063 non-null  int64
#  3   Review    39063 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 1.2+ MB

# %% [markdown]
# This is a file with 4 columns which from now on we will call variables. There is a variable called *Uniq_id* that seems to be the unique identity number of the users, but also there is other key variable, the *Username*. There is a variable type integer called *Score*, and the variable *Review*, which seems to collect information about how the users qualified the product bought. There is a total of 39063 observations, with no null data.

# %% [markdown]
# Now we are going to check the variable *Score*, we need to identify if is important the order of this variable according the comments that the users gave into the column Review.

# %%
#Check the categories of the variable score into reviews:
display(rev.Score.describe())
rev.groupby("Score").Score.count()
# Out:
# count    39063.000000
# mean         1.487648
# std          1.400332
# min          0.000000
# 25%          0.000000
# 50%          1.000000
# 75%          2.000000
# max          5.000000
# Name: Score, dtype: float64
# Score
# 0    11265
# 1    11687
# 2     7957
# 3     4007
# 4     2245
# 5     1902
# Name: Score, dtype: int64

# %% [markdown]
# The most frequency value in the reviews file is located in the score = 0, followed by the 1 score. The average of the score of the reviews is closer to 1.5, but at least the 75% of the reviews score is 2, in other words the 4.9% of the total reviews were qualified into the 5 score, it behavior begins us to give information of the reputation that have the products by the users.

# %% [markdown]
# # 2. DATA VALIDATION

# %% [markdown]
# Now that we have given a briefly revision of the data files, we are going more in the deep to check that the information counts with all the parameters that allow to make an analysis of the data and to show in a graphic way the information.

# %% [markdown]
# We are going to start with the analysis of duplicates, missing values, also we are going to sure that we count unique cases and key variables that allow us to linkage betwen the dataframes to get more information. Here we go!

# %% [markdown]
# # 2.1 Validation of duplicates, unique cases, missing values and creation of auxiliar dataframes

# %% [markdown]
# Let's begin with the **user** dataframe:

# %% [markdown]
# **2.1.1 Dataframe: user**

# %%
#Check if there are duplicates with the function .drop_duplicates():
single_user=user.drop_duplicates()
display(user.head())
#Then create an index with Username with the function .set_index():
single_user.set_index("Username", inplace=True)
single_user
# Out:
#    Username        DOB          State   Age
# 0  bkpn1412 1983-07-31         Oregon  40.0
# 1  gqjs4414 1998-07-27  Massachusetts  25.0
# 2  eehe1434 1950-08-08          Idaho  73.0
# 3  hkxj1334 1969-08-03        Florida  54.0
# 4  jjbd1412 2001-07-26        Georgia  22.0
#                 DOB          State   Age
# Username
# bkpn1412 1983-07-31         Oregon  40.0
# gqjs4414 1998-07-27  Massachusetts  25.0
# eehe1434 1950-08-08          Idaho  73.0
# hkxj1334 1969-08-03        Florida  54.0
# jjbd1412 2001-07-26        Georgia  22.0
# ...             ...            ...   ...
# mfnn1212 1997-07-27       Delaware  26.0
# ejnb3414 1976-08-01      Minnesota  47.0
# pdzw1433 1994-07-28           Ohio  29.0
# npha1342 1953-08-07        Montana  70.0
# yuoc2324 1975-08-02   South Dakota  48.0
#
# [5000 rows x 3 columns]

# %% [markdown]
# In the last code were removed the duplicates from the dataframe *user* creating a new dataframe called *single_user*.Then we create an index with the variable *Username*. Now we have three columns, including the new variable *Age*, and the index.

# %% [markdown]
# **2.1.2 Dataframe: prod**

# %%
#To check if there are NA values into the variables of the file products with the function .isna():
count_NA = prod.isna().sum()
print(count_NA.sort_values())
# Out:
# Uniq_id           0
# Name              0
# Av_Score          0
# SKU              67
# Description     543
# Price          2166
# dtype: int64

# %% [markdown]
# We can see that there are 67 NA values for the variable SKU, 543 NA values for Description, and finally as we suspected there are 2166 NA values into the variable Price. Now we know that we must be very careful when calculating descriptive values such as the median or average with the variable *Price*.

# %% [markdown]
# Now we are going to check that there are unique ID products from the dataframe that we have created before, *prod*:

# %%
#Check what are the uniques ID products with .unique():
print(prod.Uniq_id.unique())
# Out:
# ['b6c0b6bea69c722939585baeac73c13d' '93e5272c51d8cce02597e3ce67b7ad0a'
#  '013e320f2f2ec0cf5b3ff5418d688528' ... '7a8a7cba7b69b4c46ceac1d9666d84f0'
#  '9887bb20c12be3c09d094e97ac8d22be' '2cc49292b44cc12fe22206440d3e7472']

# %% [markdown]
# The same with the variable *SKU* from the dataframe *prod*.

# %%
#Check what are the uniques SKU:
print(prod.SKU.unique())
# Out:
# ['pp5006380337' 'pp5006790247' 'pp5007090172' ... 'pp5002380104'
#  'pp5002410544' 'pp5002691549']

# %% [markdown]
# We are going to remove the variables SKU and Av_Score for our analysis, from the dataframe *prod*, creating a new dataframe called *prod1*. Then we will remove the duplicates values from prod1, creating the auxiliar dataframe *single_prod1*. Finally, we will set as index the variable *Uniq_id*.

# %%
#Create a new dataframe prod1 without the variable SKU and Av_Score:
prod1=prod[["Uniq_id","Name","Description", "Price"]]
display(prod1.head())
#To drop duplicates values of the prod1:
single_prod1=prod1.drop_duplicates()
display(prod1.head())
#Then create an index with Uniq_id:
single_prod1.set_index("Uniq_id", inplace=True)
single_prod1
# Out:
#                             Uniq_id  \
# 0  b6c0b6bea69c722939585baeac73c13d
# 1  93e5272c51d8cce02597e3ce67b7ad0a
# 2  013e320f2f2ec0cf5b3ff5418d688528
# 3  505e6633d81f2cb7400c0cfa0394c427
# 4  d969a8542122e1331e304b09f81a83f6
#
#                                           Name  \
# 0  Alfred Dunner® Essential Pull On Capri Pant
# 1  Alfred Dunner® Essential Pull On Capri Pant
# 2  Alfred Dunner® Essential Pull On Capri Pant
# 3  Alfred Dunner® Essential Pull On Capri Pant
# 4  Alfred Dunner® Essential Pull On Capri Pant
#
#                                          Description  Price
# 0  Youll return to our Alfred Dunner pull-on capr...  41.09
# 1  Youll return to our Alfred Dunner pull-on capr...  41.09
# 2  Youll return to our Alfred Dunner pull-on capr...  41.09
# 3  Youll return to our Alfred Dunner pull-on capr...  41.09
# 4  Youll return to our Alfred Dunner pull-on capr...  41.09
#                             Uniq_id  \
# 0  b6c0b6bea69c722939585baeac73c13d
# ...

# %% [markdown]
# We have now the new dataframe *single_prod1* without duplicates values, and also with a new index *Uniq_id*.

# %% [markdown]
# How we see before, it is important to do a validation of the variable *Score* of the dataframe *reviews*. Let's see what is the meaning of the order of this ordinal variable.

# %% [markdown]
# **2.1.3 Dataframe: rev**

# %%
#Check any customer that has a score of 5 to understand the data, using .Score==5:
print(rev[rev.Score==5])
# Out:
#                                 Uniq_id  Username  Score  \
# 61     5abf9d28e9e0404369ece10807d99d0e  bgkj4122      5
# 72     7b16da6eaeca0ae2d107e712cfe5141d  hqju3112      5
# 85     e498aa2384360f0787701fe4ed07d8d7  hbir3342      5
# 101    4f6d3fcd5d7a7da811cca969e074db52  linr3223      5
# 103    4f6d3fcd5d7a7da811cca969e074db52  cgid3321      5
# ...                                 ...       ...    ...
# 39015  109219fc9372640a443dd3de347ec87f  irjd2214      5
# 39025  16e3ca6b6a2d3f5da9a81df6cfe7e27a  vcqh3224      5
# 39028  16e3ca6b6a2d3f5da9a81df6cfe7e27a  fcnf1412      5
# 39039  7a8a7cba7b69b4c46ceac1d9666d84f0  qven4314      5
# 39050  9887bb20c12be3c09d094e97ac8d22be  npdk2431      5
#
#                                                   Review
# 61     I was disappointed in the quality upon closer ...
# 72     I love Alfred Dunner pants and capris. These h...
# 85     I love the way these capri pants look and feel...
# ...

# %% [markdown]
# We can see that the worst comments of the customers about the quality of the product, comes from the 5 score. It give us more information than we have before.

# %% [markdown]
# Remember the dataframe *rev* that we created above?, we are going to validate this dataframe, removing duplicates and also creating an index with the *Uniq_id*, to analyse later so much the products, but then we will create other index for the users with the variable *Username*, it will have two different purposes into our analysis.

# %%
#Create a new dataframe rev1 with four variables of the dataframe:
rev1=rev[["Uniq_id","Username","Score", "Review"]]
display(rev1.head())
#To drop duplicates values:
single_rev1=rev1.drop_duplicates()
display(single_rev1.head())
#Then create and index with Username:
single_rev1.set_index(["Username"], inplace=True)
single_rev1
# Out:
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
#
#                                               Review
# 0  You never have to worry about the fit...Alfred...
# 1  Good quality fabric. Perfect fit. Washed very ...
# 2  I do not normally wear pants or capris that ha...
# 3  I love these capris! They fit true to size and...
# 4  This product is very comfortable and the fabri...
#                             Uniq_id  Username  Score  \
# 0  b6c0b6bea69c722939585baeac73c13d  fsdv4141      2
# 1  b6c0b6bea69c722939585baeac73c13d  krpz1113      1
# 2  b6c0b6bea69c722939585baeac73c13d  mbmg3241      2
# 3  b6c0b6bea69c722939585baeac73c13d  zeqg1222      0
# 4  b6c0b6bea69c722939585baeac73c13d  nvfn3212      3
#
# ...

# %% [markdown]
# We have now the next auxiliar dataframes that have been validated: **single_rev1**, **single_prod1**, and **single_user**.

# %% [markdown]
# Finally, now that we have made an enough validation into the dataframes, come on to introduce into the analysis and visualization.

# %% [markdown]
# # 3. ANALYSIS AND VISUALIZATION

# %% [markdown]
# Now that we have explored the data, it is important to understand the behaviour of the most important variables through the use of the visualization, for this purpose we are going to use specially the librarys:pandas, matplotlib.pyplot and seaborn. It allows us to analyse the data in a better way. Let's start with the customer analysis and then with the products.

# %%
#First, import the librarys to visualization and analysis:
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # 3.1 ANALYSIS OF THE USERS (Customers)

# %% [markdown]
# First, we are going to create a new dataframe which provide us of more information about the users, for this purpose we are going to use the function *merge* between the dataframes *single_rev1* and *single_user*, using as key variable the *Username*, but just by the customers who have make a review, in other words with an *inner join* by default.

# %% [markdown]
# # 3.1.1 Merge between auxiliar dataframes

# %%
#Create a data frame to merge between single_user and single_rev1, just by the clients who has make a review, 
#Using an inner join function by default:
char_user= pd.merge(single_rev1, single_user, on="Username")[["Uniq_id","Score", "State", "Age", "Review"]]

# %%
char_user.head()
# Out:
#                                    Uniq_id  Score           State   Age  \
# Username
# fsdv4141  b6c0b6bea69c722939585baeac73c13d      2  American Samoa  43.0
# fsdv4141  cbe8d131628ec67e803c47d3dd6f2529      2  American Samoa  43.0
# fsdv4141  5ea5f53bbb750106865a044634404dd7      5  American Samoa  43.0
# fsdv4141  0144d2094668b42ae7c674915806f5f3      1  American Samoa  43.0
# fsdv4141  99141a2b164cf257c96bcb4593915b50      1  American Samoa  43.0
#
#                                                      Review
# Username
# fsdv4141  You never have to worry about the fit...Alfred...
# fsdv4141  These are great shirts, looks great all day. W...
# fsdv4141  I purchase three rugs to replace twenty-year-o...
# fsdv4141  I am a huge user of BE original fromula. I hap...
# fsdv4141  Very soft and stretchy! They arent as dressy a...

# %% [markdown]
# We can see that there is a new dataframe wich is called now **char_user** with more variables added by the analysis. It has now 5 variables. Now we are going to check this new data frame:

# %%
#Check the information with .info():
char_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39080 entries, fsdv4141 to dddt3113
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Uniq_id  39080 non-null  object
#  1   Score    39080 non-null  int64
#  2   State    39080 non-null  object
#  3   Age      39080 non-null  float64
#  4   Review   39080 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# Now that we have picked up the Age of the users, we can analyse what is the score that the users give according the Age:

# %%
#Analyze the Age of users by Score using the functions groupby and describe:
print(char_user[char_user.Score.isin([0,1,2,3,4,5])].groupby("Score")["Age"].describe())
# Out:
#          count       mean        std   min   25%   50%   75%   max
# Score
# 0      11270.0  47.840816  15.045606  22.0  35.0  48.0  61.0  73.0
# 1      11690.0  47.755346  15.073636  22.0  35.0  48.0  61.0  73.0
# 2       7961.0  47.691245  14.991987  22.0  35.0  48.0  61.0  73.0
# 3       4009.0  47.554502  14.955759  22.0  35.0  48.0  60.0  73.0
# 4       2247.0  47.876725  14.807955  22.0  35.0  48.0  61.0  73.0
# 5       1903.0  47.928534  15.012933  22.0  35.0  48.0  61.0  73.0

# %% [markdown]
# We can see that for the lowest score the mean of Age is closer 48 years old, but for all the scores we can see a similar behaviour, for example, at least the 25% of the customers of all the scores (0-5) have 35 years old. The most younger customers have 22 years old.

# %% [markdown]
# Now we are going to create a scatterplot to know the distribution of the score that give the users to the products, by State and Age to check what type of information can get:

# %% [markdown]
# # 3.1.2 Distribution of the score given by the Users of the products by State and Age

# %%
#To apply the height and wide of the figure with figsize:
plt.figure(figsize=(12, 6))
#To create a scatterplot using sns, specify the axis and give color by State, here use the palette "magma":
sns.scatterplot(x='Age', y='Score', hue='State', data=char_user, palette='magma', alpha=0.7)
#To show the labels and title using plt:
plt.title('Scatter Plot by State')
plt.xlabel('Age')
plt.ylabel('Score')
#To show the legend with the name of the State "uper left":
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# We can see that there are a lot of States and also by the Age is a little difficult to understand this type of graph, for this reason we are going to create a barplot, generating the *range* of the Age to improve the visualization and also the analysis. We will remove from this analysis the variable State.

# %% [markdown]
# # 3.1.3 Frequency of the Users by Group of Age and Score

# %%
# To define the age bins, regarding the maximum and minimum value of the age:
age_bins = [0, 22, 30, 50, 100]
#To create 4 bins with the labels:
age_labels = ["22-35", "36-47", "48-60", "61+"]

# Create a new column 'AgeGroup' based on the age bins, using .cut to segment the Age:
char_user["AgeGroup"] = pd.cut(char_user["Age"], bins=age_bins, labels=age_labels, right=False)

#Plot the count of each age group by score, adjust the size of the figure (8,6):
plt.figure(figsize=(8, 6))
#Order by the score using the function range:
sns.countplot(data=char_user, x="Score", hue="AgeGroup", order= range(0,char_user["Score"].max()+1))
#To plot the title and labels:
plt.title("Count of Users by Score and Age Group")
plt.xlabel("Score")
plt.ylabel("Count")
plt.legend(title="Age Group")
plt.show()

# %% [markdown]
# We can observe that the age group with more frequency for all the scores is the range of 61 and more. Also the behaviour for all the groups of age is similar in all the scores of qualification of the products. But, we can see that for the score 1, there is a population of more than 5500 persons with 61 years old and more. In general the score with the most highest frequency for all the range of ages is 1. Did you remember that the average of the score by the users was of 1? Here is the justification!!

# %% [markdown]
# There is something that does not appear in this graph, What happened with the population in the range of age between 22-35?, Why it does not appear in the bar plot?, now we are going to make a check of this group of age:

# %%
#To review the population of 22 years old using groupby:
print(char_user[char_user.Age==22].groupby("Age").count())
# Out:
#       Uniq_id  Score  State  Review  AgeGroup
# Age
# 22.0      612    612    612     612       612

# %% [markdown]
# Definitelly, the frequency is very small how to appear on the graph.

# %% [markdown]
# Now that we have the AgeGroup variable, we are going to create an Histogram to know in small groups the frequency of the users.

# %% [markdown]
# # 3.1.4 Histogram by group of Age of the Users

# %%
#To define new age bins for this purpose, adjust the bins created before in small groups:
age_bins = [22, 27, 32, 37, 42, 47, 52, 57, 62, float('inf')]

#To label the 9 bins:
age_labels = ["22-26", "27-31", "32-36", "37-41","42-46","47-51", "52-56","57-61","62+"]

# Create a new column 'AgeGroup' based on the age bins:
char_user["AgeGroup"] = pd.cut(char_user["Age"], bins=age_bins, labels=age_labels, right=False)

#To plot the Histogram in a size of (8,6):
plt.figure(figsize=(8,6))
#Use sns and for the parameter discrete=True, which indicates that the bin breaks represent the unique values in the dataset:
sns.histplot(data=char_user, x="AgeGroup", bins=len(age_labels), discrete=True, shrink=0.8)
#To plot the title and labels of the axis:
plt.title("Histogram of Users by Age Group")
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The range of age with the major frequency in the Histogram goes from 61 years old and more, followed by the users between 57 and 61 years old, and in third place is the group of age in the range between 47 and 51.

# %% [markdown]
# Now we are going to create a scatterplot by Group of Age and Score, but classified by State.

# %% [markdown]
# # 3.1.5 Distribution of the score given by the Users of the products by Group of Age and State

# %%
#To plot the figure in a dimension (10,6):
plt.figure(figsize=(10, 6))
#Use sns to show the scatterplot, the hue value allow us to make the color by State, using the palette "plasma":
sns.scatterplot(x='AgeGroup', y='Score', hue='State', data=char_user, palette='plasma', alpha=0.8)
#To show the title and the labels of the axis:
plt.title('Scatter Plot by State')
plt.xlabel('AgeGroup')
plt.ylabel('Score')
#To show the legend with the States:
plt.legend(title='State', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# Now it is more easy to interpret, that for example, New York has the best score by the users in the range of age between 22 until 26 years old. Also, that the State of Mississippi has the score of 4 by the users in the range of age between 42 until 46 year sold.

# %% [markdown]
# Now, to know about the behaviour of the customers by State is very interesting, overall when the manager of a store want to know how are the sells by location. Are working good the sells in any specific location? or perhaps, Do we need to close or increase the products? For this reason we are going to do a choroplethic map, for this purpose we need to install the package *geopandas*. Here we go!

# %% [markdown]
# We are going to create a choroplethic map using the library requests to import the USA map from the webpage, in this case we need to download the shape file, to import the coordenates of the map of the USA. I have searched the file in this web page of the Census Bureau of the USA: https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_state_5m.zip.
#
# We need to import the module: requests, that is a library for making HTTP requests, also the standard library zipfile, to manipulate zip files, and finally, the io module that allows us to manage the file-related input and output operations.

# %%
# !pip install geopandas

# %%
#Import all the librarys required specific for the choroplethic map:
import geopandas as gpd
import requests
import zipfile
import io

# %%
#URL to the shapefile zip of the USA from:
shapefile_url = 'https://www2.census.gov/geo/tiger/GENZ2021/shp/cb_2021_us_state_5m.zip'

# %%
#To download the shapefile zip using requests.get() from the url:
r = requests.get(shapefile_url)

# %%
# To extract the zip file using .extractall:
z = zipfile.ZipFile(io.BytesIO(r.content))
z.extractall('C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment')

# %%
#To read the shapefile from the local folder with .read_file:
path2='C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/cb_2021_us_state_5m.shp'
geodf_usa = gpd.read_file(path2)

# %%
#To check the column names in geodf_usa and our dataframe char_user for merging:
print(geodf_usa.columns)
print(char_user.columns)
# Out:
# Index(['STATEFP', 'STATENS', 'AFFGEOID', 'GEOID', 'STUSPS', 'NAME', 'LSAD',
#        'ALAND', 'AWATER', 'geometry'],
#       dtype='object')
# Index(['Uniq_id', 'Score', 'State', 'Age', 'Review', 'AgeGroup'], dtype='object')

# %%
#To merge with the DataFrame char_user by left_on NAME and right_on State, by the how= left join:
merg_usa = geodf_usa.merge(char_user, left_on='NAME', right_on='State', how='left')

# %% [markdown]
# Once we have imported all the librarys, downloaded the zip file, extracted it and also merged by the variable *NAME* of the shape file and *State* of the char_user dataframe, we are ready to plot the choroplethic map, with the library matplotlib.pyplot.

# %% [markdown]
# We are going to graph with a heather line that varies in strong and soft red tones between the States of USA, with a score of 5 being the warmest Score. We can see the cmap parameter = RdPu, which is a sequencial colormaps tool of matplotlib: https://matplotlib.org/stable/users/explain/colors/colormaps.html, showing us in this case the variation of heat in purple tones.

# %%
#Subplot one figure with the dimension (20,15):
fig, ax = plt.subplots(1, 1, figsize=(20, 15))
#Plot the merge between the shape file of USA and the file char_user, add a line of heat in purple tones that vary by Score:
merg_usa.plot(column='Score', cmap='RdPu', linewidth=0.8, ax=ax, edgecolor='0.8', legend=True)
#To add the title:
ax.set_title('Choropleth Map of Scores by State')
plt.show()

# %% [markdown]
# We can see that according the States of the USA, Montana, South Dakota, Kentucky and Georgia, are the States where the Score is the lowest about the criteria of evaluation of the customers by products. By other way, California, Nevada and Oregon have the best score about the revision of the reviews about the products.

# %% [markdown]
# # 3.2 ANALYSIS OF THE PRODUCTS

# %% [markdown]
# Now that we have finished with the revision of the customers, we are going to check what is the behaviour of the products. We are going to use the dataframe **prod**.

# %% [markdown]
# First, we are going to create a diagram of distribution of the price by the Score, using the library pandas.

# %% [markdown]
# # 3.2.1 Analysis of outliers

# %%
#To create a scatterplot for the price using plot.scatter():
prod.plot.scatter(x = 'Av_Score', y = 'Price')
# Out:
# <Axes: xlabel='Av_Score', ylabel='Price'>

# %% [markdown]
# As we had observed before, there is a product which price is around the 17500, and also the average of the score of this one is in the half (3). Do you remember that we saw before it as an outlier? It is more clear with a scatterplot! Also, we can see that the distribution of the prices of the products concentrate in the range less than 2500. The most important concentration of the products is between the average scores of 2 and 3.5. There are few prices of products that have an average score of 5. Also, we can see that although the price of one of the products is over the 12500 it has an average score of 1, in other words the customer has good qualification of this product although the price is high.

# %% [markdown]
# Now we are going to analyze from the dataframe char_user information about the products.

# %%
#To check the names of the dataframa char_user:
char_user.columns
# Out:
# Index(['Uniq_id', 'Score', 'State', 'Age', 'Review', 'AgeGroup'], dtype='object')

# %% [markdown]
# In this case, we are going to create a new dataframe with a new index using char_user:

# %%
#Create a new dataframe char_user_1 to analyze the products, selecting the variables Uniq_id, Score, Age, State,and AgeGroup:
char_user_1=char_user[["Uniq_id", "Score", "Age", "State", "AgeGroup"]]
display(char_user_1.head())
# Out:
#                                    Uniq_id  Score   Age           State  \
# Username
# fsdv4141  b6c0b6bea69c722939585baeac73c13d      2  43.0  American Samoa
# fsdv4141  cbe8d131628ec67e803c47d3dd6f2529      2  43.0  American Samoa
# fsdv4141  5ea5f53bbb750106865a044634404dd7      5  43.0  American Samoa
# fsdv4141  0144d2094668b42ae7c674915806f5f3      1  43.0  American Samoa
# fsdv4141  99141a2b164cf257c96bcb4593915b50      1  43.0  American Samoa
#
#          AgeGroup
# Username
# fsdv4141    42-46
# fsdv4141    42-46
# fsdv4141    42-46
# fsdv4141    42-46
# fsdv4141    42-46

# %% [markdown]
# Now we are going to check the duplicates values in the new dataframe:

# %%
#To drop duplicates values of the dataframe char_user_1:
char_user_1=char_user_1.drop_duplicates()
display(char_user_1.head())
# Out:
#                                    Uniq_id  Score   Age           State  \
# Username
# fsdv4141  b6c0b6bea69c722939585baeac73c13d      2  43.0  American Samoa
# fsdv4141  cbe8d131628ec67e803c47d3dd6f2529      2  43.0  American Samoa
# fsdv4141  5ea5f53bbb750106865a044634404dd7      5  43.0  American Samoa
# fsdv4141  0144d2094668b42ae7c674915806f5f3      1  43.0  American Samoa
# fsdv4141  99141a2b164cf257c96bcb4593915b50      1  43.0  American Samoa
#
#          AgeGroup
# Username
# fsdv4141    42-46
# fsdv4141    42-46
# fsdv4141    42-46
# fsdv4141    42-46
# fsdv4141    42-46

# %% [markdown]
# Now is time to reset in this new dataframe *char_user_1*, the last index that we have created in the dataframe char_user, the new index for the purpose of analyze the products is now *Uniq_id*, in the dataframe *char_user_2*.

# %% [markdown]
# # 3.2.2 Resetting index

# %%
#Resetting the index in the new dataframe with Uniq_id:
char_user_2=char_user_1.reset_index().set_index("Uniq_id")
char_user_2
# Out:
#                                   Username  Score   Age                 State  \
# Uniq_id
# b6c0b6bea69c722939585baeac73c13d  fsdv4141      2  43.0        American Samoa
# cbe8d131628ec67e803c47d3dd6f2529  fsdv4141      2  43.0        American Samoa
# 5ea5f53bbb750106865a044634404dd7  fsdv4141      5  43.0        American Samoa
# 0144d2094668b42ae7c674915806f5f3  fsdv4141      1  43.0        American Samoa
# 99141a2b164cf257c96bcb4593915b50  fsdv4141      1  43.0        American Samoa
# ...                                    ...    ...   ...                   ...
# 307e9f01bb5c6c0fd6b4cee74828c22c  zmon4424      1  22.0  District of Columbia
# add769ea4635149ad92c0b01fd5d31ac  hnxb3322      2  47.0           Connecticut
# 1382f508f14050ae2013dd215ed2b82f  jhof4341      2  35.0         New Hampshire
# f08c827fb5b4b4533bd9ec6e42dedff8  jhof4341      0  35.0         New Hampshire
# 9aed892fd225eb90ddee0979da5bce84  dddt3113      0  29.0               Alabama
#
# ...

# %% [markdown]
# We are ready to make a merge between the dataframes *char_user_2* and *prod_json*:

# %%
#Check the columns of the dataframe prod_json to merge with char_user_2:
prod_json.columns
# Out:
# Index(['index', 'sku', 'name_title', 'description', 'list_price', 'sale_price',
#        'category', 'category_tree', 'average_product_rating', 'product_url',
#        'product_image_urls', 'brand', 'total_number_reviews', 'Reviews',
#        'Bought With'],
#       dtype='object')

# %%
#To look the first 10 lines:
print(prod_json.head())
# Out:
#                                   index           sku  \
# uniq_id
# b6c0b6bea69c722939585baeac73c13d      0  pp5006380337
# 93e5272c51d8cce02597e3ce67b7ad0a      1  pp5006380337
# 013e320f2f2ec0cf5b3ff5418d688528      2  pp5006380337
# 505e6633d81f2cb7400c0cfa0394c427      3  pp5006380337
# d969a8542122e1331e304b09f81a83f6      4  pp5006380337
#
#                                                                    name_title  \
# uniq_id
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
# 93e5272c51d8cce02597e3ce67b7ad0a  Alfred Dunner® Essential Pull On Capri Pant
# 013e320f2f2ec0cf5b3ff5418d688528  Alfred Dunner® Essential Pull On Capri Pant
# 505e6633d81f2cb7400c0cfa0394c427  Alfred Dunner® Essential Pull On Capri Pant
# d969a8542122e1331e304b09f81a83f6  Alfred Dunner® Essential Pull On Capri Pant
#
#                                                                         description  \
# uniq_id
# ...

# %%
#To check the index of the new dataframe char_user_2:
char_user_2.index
# Out:
# Index(['b6c0b6bea69c722939585baeac73c13d', 'cbe8d131628ec67e803c47d3dd6f2529',
#        '5ea5f53bbb750106865a044634404dd7', '0144d2094668b42ae7c674915806f5f3',
#        '99141a2b164cf257c96bcb4593915b50', '7c27ffd820cbe7041c2a8bd0ca92a232',
#        'f9f25236d8124fd499aeb4acf622bbae', '54b8515077d35bbe1718aa35fbb5603a',
#        'b232c9e48cd9de05c69d9f6776bd0be3', 'b6c0b6bea69c722939585baeac73c13d',
#        ...
#        'd1fefd22e1b5e57c432be94e24b6dbab', '729a10eaf80821b364e9ac547de9ba31',
#        'd4d423d46bc76be4db768c2b0ea5816b', 'cbe90f3c8e889a86169a903c47f83aa3',
#        'cc24e1d5f011291c9cc450e65f11d24f', '307e9f01bb5c6c0fd6b4cee74828c22c',
#        'add769ea4635149ad92c0b01fd5d31ac', '1382f508f14050ae2013dd215ed2b82f',
#        'f08c827fb5b4b4533bd9ec6e42dedff8', '9aed892fd225eb90ddee0979da5bce84'],
#       dtype='object', name='Uniq_id', length=39072)

# %%
#Rename the index name with uniq_id:
char_user_2.index.name = "uniq_id"
char_user_2.index
# Out:
# Index(['b6c0b6bea69c722939585baeac73c13d', 'cbe8d131628ec67e803c47d3dd6f2529',
#        '5ea5f53bbb750106865a044634404dd7', '0144d2094668b42ae7c674915806f5f3',
#        '99141a2b164cf257c96bcb4593915b50', '7c27ffd820cbe7041c2a8bd0ca92a232',
#        'f9f25236d8124fd499aeb4acf622bbae', '54b8515077d35bbe1718aa35fbb5603a',
#        'b232c9e48cd9de05c69d9f6776bd0be3', 'b6c0b6bea69c722939585baeac73c13d',
#        ...
#        'd1fefd22e1b5e57c432be94e24b6dbab', '729a10eaf80821b364e9ac547de9ba31',
#        'd4d423d46bc76be4db768c2b0ea5816b', 'cbe90f3c8e889a86169a903c47f83aa3',
#        'cc24e1d5f011291c9cc450e65f11d24f', '307e9f01bb5c6c0fd6b4cee74828c22c',
#        'add769ea4635149ad92c0b01fd5d31ac', '1382f508f14050ae2013dd215ed2b82f',
#        'f08c827fb5b4b4533bd9ec6e42dedff8', '9aed892fd225eb90ddee0979da5bce84'],
#       dtype='object', name='uniq_id', length=39072)

# %% [markdown]
# We have renamed the new index of char_user_2 with *uniq_id*, we can make a merge between *char_user_2* and *prod_json*, the merge will be an inner join, with left_on and right_on by the uniq_id, to get all the neccesary variables with information of left and right.

# %% [markdown]
# # 3.2.3 Merge between auxiliar dataframes

# %%
#To create other data frame with merge between char_user_2 and prod_json, using by default inner join method: 
char_prod= pd.merge(char_user_2, prod_json, left_on="uniq_id",right_on="uniq_id")[["sale_price",
                                                                                   "brand",
                                                                                   "name_title",
                                                                                   "average_product_rating",
                                                                                   "Score", 
                                                                                   "State", 
                                                                                   "Age"]]

# %%
char_prod.head()
# Out:
#                                  sale_price          brand  \
# uniq_id
# b6c0b6bea69c722939585baeac73c13d      24.16  Alfred Dunner
# b6c0b6bea69c722939585baeac73c13d      24.16  Alfred Dunner
# b6c0b6bea69c722939585baeac73c13d      24.16  Alfred Dunner
# b6c0b6bea69c722939585baeac73c13d      24.16  Alfred Dunner
# b6c0b6bea69c722939585baeac73c13d      24.16  Alfred Dunner
#
#                                                                    name_title  \
# uniq_id
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
# b6c0b6bea69c722939585baeac73c13d  Alfred Dunner® Essential Pull On Capri Pant
#
#                                   average_product_rating  Score  \
# uniq_id
# ...

# %% [markdown]
# The new dataframe is called *char_prod*, with the key variable *uniq_id* and 7 variables.

# %% [markdown]
# Let's do it a barplot to understand the frequency by brand of product.

# %% [markdown]
# # 3.2.4 Top ten brands of products

# %%
#To count the top ten brands using .value_counts()[:10]:
char_prod['brand'].value_counts()[:10]
# Out:
# LIZ CLAIBORNE           2134
# ARIZONA                 1983
# STAFFORD                1520
# St. John's Bay          1454
# Xersion                 1426
# Asstd National Brand    1111
# A.N.A                   1109
# WORTHINGTON             1049
# JCP HOME                 967
# Nike                     887
# Name: brand, dtype: int64

# %% [markdown]
# The first place is occupied by LIZ CLAIBORNE, it is the brand with more products. The last place goes to Nike brand, with 887 products of this brand in the store JCPenney.

# %%
#To do a barplot with the top ten brands:
#To adjust the figure dimensions:
sns.set(rc={'figure.figsize':(15,5)})
#To create the top ten products, groupby brand and sorted by Score:
top_ten_prod = char_prod.groupby('brand', as_index=False)['Score'].sum().sort_values(by='Score', ascending=False).head(10)
#Plot the top ten brands:
sns.barplot(data=top_ten_prod, x='brand', y='Score', hue='brand', dodge=False).set(xticklabels=[]);

# %% [markdown]
# We can see that with the help of the library seaborn the top of the brands is LIZ CLAIRBORNE, with the most highest score, followed by ARIZONA, and in third place St.John's Bay. The last brand in the top ten is Levi.

# %% [markdown]
# Now we are going to choose a State and analyze what is the behaviour of the brands of the products. In this case we are going to choose New York.

# %%
#Create a new dataframe just with the information of the State of New York:
NY_brands = char_prod[char_prod.State=='New York'][['brand','name_title','sale_price','average_product_rating','Score', 'Age']]
#Drop duplicates:
NY_brands.drop_duplicates(inplace = True)
NY_brands.head()
# Out:
#                                         brand  \
# uniq_id
# f9f25236d8124fd499aeb4acf622bbae       Avanti
# 54b8515077d35bbe1718aa35fbb5603a  JF J.Ferrar
# 904aae9df04c86b9b3982976eadbf378  BELLE + SKY
# bb0ccedd74917e6c562eb13623098069  JF J.Ferrar
# 72a1c12866274133e38ed4ea4d66708c  MIXIT TREND
#
#                                                                          name_title  \
# uniq_id
# f9f25236d8124fd499aeb4acf622bbae                   Avanti Kokopelli Bath Collection
# 54b8515077d35bbe1718aa35fbb5603a  JF J. Ferrar® Stretch Gabardine Suit Separates...
# 904aae9df04c86b9b3982976eadbf378             BELLE + SKY™ Long-Sleeve Sweater Tunic
# bb0ccedd74917e6c562eb13623098069  JF J. Ferrar Black Nailhead Slim-Fit Suit Sepa...
# 72a1c12866274133e38ed4ea4d66708c                 Mixit™ Pom-Pom Sweater Newsboy Hat
#
#                                  sale_price  average_product_rating  Score  \
# uniq_id
# ...

# %% [markdown]
# Now that we have selected New York, let's check, What are the top ten brands in this State?

# %%
#Show what is the top ten brand in the State of New York:
#Using groupby and the function value_counts()[:10]:
print(NY_brands.groupby('brand').value_counts()[:10])
# Out:
# brand  name_title                                        sale_price  average_product_rating  Score  Age
# A.N.A  a.n.a® 3/4-Sleeve Peasant Blouse                  24.60       4.500000                5      49.0    1
#        a.n.a® Crochet Lace-Hem Tank Top                  18.12       1.666667                3      30.0    1
#        a.n.a® Thickstitch Bootcut Jeans                  36.25       4.375000                0      22.0    1
#        a.n.a® Dolman-Sleeve Ribbed Sweater - Plus        18.90       3.111111                1      67.0    1
#        a.n.a® Drape Front Jacket - Tall                  12.07       2.727273                4      36.0    1
#        a.n.a® Draped Bandeau One-Piece Swimdress - Plus  66.46       2.500000                0      23.0    1
#        a.n.a® Heather Wedge Pumps                        47.29       3.125000                0      60.0    1
# ...

# %% [markdown]
# The most important brand is A.N.A in the store of JCPenney located in New York.

# %% [markdown]
# Now, although it is part of the last part of this assignment, we are going to create an image with this brand in New York!
# Note:It is important to mention that to get this image we have to already have installed opencv-python. We will see in deepth in the last part this chapter, no worry! But here we go with the librarys required.

# %%
#Firs of all we are going to install opencv:
# !pip install opencv-python

# %%
#Import the nex librarys:
import cv2

# %% [markdown]
# Here we use the function imread() to load an image from a file. The function imread loads an image from the specified file and returns it. Then imshow() print the image.

# %%
path3='C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/ANA.jpg'
ANA_logo = cv2.imread(path3)
plt.imshow(ANA_logo)
plt.title('ANA_logo')
plt.show()

# %% [markdown]
# Now we are going to remove the axis of the image, and also improve the RGB colours that by default is launching the image.

# %%
#To change the order of cvtColor using .COLOR_BGR2RGB:
ANA_logo = cv2.cvtColor(ANA_logo, cv2.COLOR_BGR2RGB)
#To show the image using imshow():
plt.imshow(ANA_logo)
#To show the title and remove the axis:
plt.title('ANA_logo')
plt.axis('off')
#To plot the image:
plt.show()
print(ANA_logo.shape)
# Out:
# (156, 324, 3)

# %% [markdown]
# Below we will review this topic of data augmented  in depth :).

# %% [markdown]
# # 3.3 ANALYSIS OF SENTIMENTS OF THE CUSTOMERS

# %% [markdown]
# Other tool to analyze how the customers feel about the products, is using the Natural Language Process (NLP). There is a package in Python called NLTK, or Natural Language Toolkit, which is a Python package that you can use for NLP. There is a lot of the information that could be analyzed but is unstructured data and contains human-readable text.

# %% [markdown]
# Now we are going to use NLP into our data. First, install nltk.

# %%
# !pip install nltk

# %%
#Import the librarys:
import nltk

# %% [markdown]
# Now we need the *gutenberg* resource. We are going to download.

# %%
#Download the gutenberg resource:
nltk.download('gutenberg')
# Out:
# [nltk_data] Downloading package gutenberg to
# [nltk_data]     C:\Users\SONIA\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# True

# %% [markdown]
# We need to import the next packages: nltk and also from nltk.sentiment.vader import the *SentimentIntensityAnalyzer*.

# %%
#Import the next packages:
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %% [markdown]
# Now we are going to add a sentimental analysis of the variable *Review* to analize how the users feel about the products. Come back at the dataframe *char_user*:

# %%
char_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39080 entries, fsdv4141 to dddt3113
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Uniq_id   39080 non-null  object
#  1   Score     39080 non-null  int64
#  2   State     39080 non-null  object
#  3   Age       39080 non-null  float64
#  4   Review    39080 non-null  object
#  5   AgeGroup  39080 non-null  category
# dtypes: category(1), float64(1), int64(1), object(3)
# memory usage: 2.8+ MB

# %% [markdown]
# Split the text of the column *Review*, first we are going to explore this column, and we can see that they are performed as sentences.

# %%
char_user["Review"]
# Out:
# Username
# fsdv4141    You never have to worry about the fit...Alfred...
# fsdv4141    These are great shirts, looks great all day. W...
# fsdv4141    I purchase three rugs to replace twenty-year-o...
# fsdv4141    I am a huge user of BE original fromula. I hap...
# fsdv4141    Very soft and stretchy! They arent as dressy a...
#                                   ...
# zmon4424    Size chart suggested I order size 6, my usual ...
# hnxb3322    I bought a pair of Xersion Yoga pants several ...
# jhof4341    Impressed with the detailing - back pleats, st...
# jhof4341    Use these for golf slacks. Dont get in my way....
# dddt3113    I purchased this based on past Stafford purcha...
# Name: Review, Length: 39080, dtype: object

# %% [markdown]
# Now, we can check the polarity of sentiments, Let's do it!

# %% [markdown]
# # 3.3.1 Polarity

# %% [markdown]
# Now we need to import from *textblob* from TextBlob, which is a Lexicon-based sentiment analyzer that has some predefined rules, in other words, it has word and weight dictionary, where it has some scores that help to calculate a sentence's polarity.

# %%
#Import the next librarys to analyse the sentiments of the column Review:
from textblob import TextBlob

# %% [markdown]
# We are going to create a function that allow us to get the sentiment polarity:

# %%
# Create a function to get sentiment polarity with def and return:
def get_sentiment(text):
    analysis = TextBlob(text)
    return analysis.sentiment.polarity

# %% [markdown]
# Now we are going to apply the function over the column *Review*. We are going to store the results in a new column called *Sentiment*

# %%
# Apply the function to the 'Review' column of the char_user dataframe:
char_user['Sentiment'] = char_user['Review'].apply(get_sentiment)

# %% [markdown]
# We are going to use a lambda function and an if else conditional, to classify the sentiments as: Positive, Negative or Neutral.

# %%
# Classify sentiments as positive, negative, or neutral using lambda function if x>0 'Positive', if x<0 'Negative' else 'Neutral'.
char_user['Sentiment_Class'] = char_user['Sentiment'].apply(lambda x: 'Positive' if x > 0 
                                                            else ('Negative' if x < 0 
                                                                else 'Neutral'))

# %% [markdown]
# Finally, print the results with all the columns created:

# %%
# Display the results of the dataframe char user that applied the lambda function for sentiment analysis:
print(char_user[['Review', 'Score','Sentiment', 'Sentiment_Class']])
# Out:
#                                                      Review  Score  Sentiment  \
# Username
# fsdv4141  You never have to worry about the fit...Alfred...      2   0.575000
# fsdv4141  These are great shirts, looks great all day. W...      2   0.800000
# fsdv4141  I purchase three rugs to replace twenty-year-o...      5   0.233333
# fsdv4141  I am a huge user of BE original fromula. I hap...      1   0.102020
# fsdv4141  Very soft and stretchy! They arent as dressy a...      1   0.162500
# ...                                                     ...    ...        ...
# zmon4424  Size chart suggested I order size 6, my usual ...      1   0.309679
# hnxb3322  I bought a pair of Xersion Yoga pants several ...      2   0.287500
# jhof4341  Impressed with the detailing - back pleats, st...      2   0.252083
# jhof4341  Use these for golf slacks. Dont get in my way....      0   0.000000
# dddt3113  I purchased this based on past Stafford purcha...      0   0.275000
#
# ...

# %%
#To check the last data frame with the new information of the Users:
char_user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39080 entries, fsdv4141 to dddt3113
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Uniq_id          39080 non-null  object
#  1   Score            39080 non-null  int64
#  2   State            39080 non-null  object
#  3   Age              39080 non-null  float64
#  4   Review           39080 non-null  object
#  5   AgeGroup         39080 non-null  category
#  6   Sentiment        39080 non-null  float64
#  7   Sentiment_Class  39080 non-null  object
# dtypes: category(1), float64(2), int64(1), object(4)
# memory usage: 3.4+ MB

# %% [markdown]
# We have in our dataframe *char_user* new columns or variables, in total 8 variables including the Uniq_id of the product. It is a little difficult to check the results of sentiment without a graph. Let's do it a boxplot to review the polarity of the sentiments, but before we can use the function groupby to know more about this classification.

# %%
#Group by the variable Sentiment_Class using .Sentiment_Class:
char_user.groupby("Sentiment_Class").Sentiment_Class.count()
# Out:
# Sentiment_Class
# Negative     2676
# Neutral      1196
# Positive    35208
# Name: Sentiment_Class, dtype: int64

# %% [markdown]
# We can see that the highest frequency is concentrated in positive comments from users about the products. In other words around the 90% of the users have positive comments about the products of JCPenney.

# %% [markdown]
# Finally, we are going to create a boxplot classified by Group of Ages to analyze the polarity of the sentiment analysis.

# %%
#Create bins to the ranges of age:
age_bins = [0, 22, 30, 50, 100]  
age_labels = ["22-35", "36-47", "48-60", "61+"]

#Segment with .cut and sort data values into bins:
char_user['Age_Group'] = pd.cut(char_user['Age'], bins=age_bins, labels=age_labels, right=False)

# Create a boxplot
plt.figure(figsize=(10, 6))
#Using the Sentiment class to classify the boxplots:
sns.boxplot(x='Age_Group', y='Sentiment', hue='Sentiment_Class', data=char_user)
#Plot the title and labels:
plt.title('Boxplot of Sentiment Scores by Age Group and Sentiment Class')
plt.xlabel('Age Group')
plt.ylabel('Sentiment Score')
plt.legend(title='Sentiment Class', loc='upper right')
plt.show()

# %% [markdown]
# We can see that for the age of group between 36 until 47 years old, and also by the range between 48 until 60 years old, and more than 61 there is a similar behaviour specially about the positive polarity, been the median value over 0.25 sentiment score.

# %% [markdown]
# # 3.3.2 Wordcloud

# %% [markdown]
# Now we are going to use the same variable Review to create a Wordcloud, for this purpose we need install the library wordcloud.

# %%
#To create a wordcloud with the reviewers dataframe:
# !pip install wordcloud

# %% [markdown]
# Import the next librarys:

# %%
#Import the librarys to make a wordcloud:
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator 
from nltk.corpus import stopwords

# %% [markdown]
# Creare a new dataframe with the column Review from the char_user dataframe:

# %%
#Create a new dataframe from char_user:
reviews_WC = char_user['Review']
reviews_WC.head()
# Out:
# Username
# fsdv4141    You never have to worry about the fit...Alfred...
# fsdv4141    These are great shirts, looks great all day. W...
# fsdv4141    I purchase three rugs to replace twenty-year-o...
# fsdv4141    I am a huge user of BE original fromula. I hap...
# fsdv4141    Very soft and stretchy! They arent as dressy a...
# Name: Review, dtype: object

# %%
#To review the information:
reviews_WC.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 39080 entries, fsdv4141 to dddt3113
# Series name: Review
# Non-Null Count  Dtype
# --------------  -----
# 39080 non-null  object
# dtypes: object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# We need to remove the actual index in this new dataframe to create the wordcloud. For this purpose we are going to use reset_index:

# %%
#To use the values of the core. serie in pandas, we are going to reset the original index for the purpose to create a wordcloud: 
reviews_WC1 = reviews_WC.reset_index(drop=True).to_frame()
reviews_WC1.head()
# Out:
#                                               Review
# 0  You never have to worry about the fit...Alfred...
# 1  These are great shirts, looks great all day. W...
# 2  I purchase three rugs to replace twenty-year-o...
# 3  I am a huge user of BE original fromula. I hap...
# 4  Very soft and stretchy! They arent as dressy a...

# %%
# Generate a word cloud image with the text Review with .generate() method:
wordcloud = WordCloud().generate(' '.join(reviews_WC1['Review']))

# %%
# Display the generated image with .imshow and bilinear interpolation:
plt.imshow(wordcloud, interpolation='bilinear')
#Plot without the axis:
plt.axis("off")
plt.show()

# %% [markdown]
# This code generates a word cloud image from the text of a single review.
# 1. First, the code selects the text of the first review from the dataframe reviews_WC1 and assigns it to the variable Review.
# 2. Next, the code creates a WordCloud object and generates a word cloud image from the text using the generate() method.
# 3. Finally, the code displays the generated image using imshow() and turns off the axis using axis("off").
# The image is then shown using show().
# Note: A bilinear interpolation is the distance weighted average of the four nearest pixel values to estimate a new pixel value.

# %% [markdown]
# We can see as a result of the wordcloud the reviews made from the customers about the products are more positive because you can see in a long size the words: love, fit, comfortable, great.

# %% [markdown]
# # 4. DATA AUGMENTATION

# %% [markdown]
# Now we are going to finish placed the logo of the J.C.PenneyCo. using the computer vision and OpenCV which according Mordvintsev (2017), was used on *Stanley*, the vehicle who won 2005 DARPA Grand Challenge. Nowadays, OpenCV have converted in a good support in the use of a lot of algorithms related to Computer Vision and Machine Learning and it is beginning to get more importance.

# %%
#Firs of all we are going to install opencv:
# !pip install opencv-python

# %% [markdown]
# We already have imported the library cv2, but with the purposes to ecplain how it works we are going to do again, but also we have to remember that for this case we should have imported the library matplotlib.

# %%
#Import the librarys required:
import cv2

# %% [markdown]
# Now we are going to create a Numpy array, which for storing an image is a height by width by three array of 8 bit, nameless *integers*. That means they can store whole numbers from 0 to 255. Let's create a simple 600 by 450 rectangle with all the colours set to white, to get this one we have to multiply the array of 8 bit by 255. Let´s see how it works.

# %%
#To get a white rectangle with the dimensions (600, 450):
img1 = np.ones((600,450,3),np.uint8)*255
#To show the image using .imshow():
plt.imshow(img1)
#To show the title of the image:
plt.title('All White')
plt.show()

# %% [markdown]
# We can see how the shape of the Numpy array - 600 by 450 corresponds to the shape of the image - 600 pixels high and 450 wide. All pixels have a colour code of zero, zero, zero, which means no red, green or blue, so it is black, however when we mulyiply by 255 it converts in white.

# %% [markdown]
# Now we are going to load an image from the web page with the logo of the enterprise J.C.PenneyCo. to allow us to introduce our first OpenCV function *imread* which reads an image from a file. Let's do it.

# %%
#To read the image with cv2.imread():
path4='C:/Users/SONIA/Desktop/Msc. Data Science/Autum/Representing and manipulating data/main_assignment/Logo.jpg'
Logo_JCPenney = cv2.imread(path4)
#To show the image with imshow():
plt.imshow(Logo_JCPenney)
#To plot the title:
plt.title('Logo_JCPenney')
plt.show()

# %% [markdown]
# The colours don't look similar at the original image, matplotlib expects RGB but opencv uses BGR as default. That is the same way of representing colours, but with the values in a different order. For this reason we need to translate the colour scheme, which I can do with openCV. Then I'll remove the axis lines and print the shape of the array too.

# %%
#To change the order of BGR by RGB using cv2.COLOR_BGR2RGB:
Logo_JCPenney = cv2.cvtColor(Logo_JCPenney, cv2.COLOR_BGR2RGB)
#To show the image using imshow():
plt.imshow(Logo_JCPenney)
#To plot the title:
plt.title('Logo_JCPenney')
#To remove the axis:
plt.axis('off')
#To show the image with the changes:
plt.show()
print(Logo_JCPenney.shape)
# Out:
# (554, 425, 3)

# %% [markdown]
# Finally, what happens if we reduce the amount of one of the colour components? Let's try changing the amount of blue in the image.

# %%
#To copy the image in a new object .copy():
blueLogo_JCPenney = Logo_JCPenney.copy()
#To reduce the amount of the colour component blue, divided by 2; and changing the value of the third numpy array by 2:
blueLogo_JCPenney[:,:,2] = Logo_JCPenney[:,:,2]/2
#To plot the new image with the changes using imshow():
plt.imshow(blueLogo_JCPenney)
plt.show()

# %% [markdown]
# This color is very nice!Now we can rotate an image too at 15 grades, as you can see here, to look as a nice newspaper cover!! Also we will remove the axis line. Let's do it.

# %%
#To conserve the last image reduced the colour blue:
height,width,_ = blueLogo_JCPenney.shape
#To rotate the image at 15 grades, as a matrix in 2D:
rotation_matrix = cv2.getRotationMatrix2D((width/2, height/2), 15, 1)
# To apply a rotation to the image after being transformed using .warpAffine():
rotated_image = cv2.warpAffine(blueLogo_JCPenney, rotation_matrix, (width, height))
#To show the image:
plt.imshow(rotated_image)
#To remove the axis:
plt.axis('off')
plt.show()

# %% [markdown]
# # Conclusions:

# %% [markdown]
# 1.-The age group with more frequency for all the scores is the range of 61 and more. Also the behaviour for all the groups of age is similar in all the scores of qualification of the products. But, we can see that for the score 1, there is a population of more than 5500 persons with 61 years old and more. In general the score with the most highest frequency for all the range of ages is 1.

# %% [markdown]
# 2.- The range of age with the major frequency in the Histogram goes from 61 years old and more, followed by the users between 57 and 61 years old, and in third place is the group of age in the range between 47 and 51.

# %% [markdown]
# 3.- New York has the best score by the users in the range of age between 22 until 26 years old.

# %% [markdown]
# 4.- Montana, South Dakota, Kentucky and Georgia, are the States where the Score is the lowest about the criteria of evaluation of the customers by products. By other way, California, Nevada and Oregon have the best score about the revision of the reviews about the products.

# %% [markdown]
# 5.- The distribution of the prices of the products concentrate in the range less than 2500. The most important concentration of the products is between the average scores of 2 and 3.5. There are few prices of products that have an average score of 5. Also, we can see that although the price of one of the products is over the 12500 it has an average score of 1, in other words the customer has good qualification of this product although the price is high.

# %% [markdown]
# 6.- The top of the brands is LIZ CLAIRBORNE, with the most highest score, followed by ARIZONA, and in third place St.John's Bay. The last brand in the top ten is Levi.

# %% [markdown]
# 7.- The most important brand is A.N.A in the store of JCPenney located in New York.

# %% [markdown]
# 8.- For the age group between 36 until 47 years old, and also by the range between 48 until 60 years old, and more than 61 there is a similar behaviour specially about the positive polarity, been the median value over 0.25 sentiment score.

# %% [markdown]
# 9.- The reviews made from the customers about the products are more positive because you can see in a long size the words: love, fit, comfortable, great.

# %% [markdown]
# # Recommendations:

# %% [markdown]
# 1.- I can recommend that in the case of the products, the manager of sells could review the relationship between the price and the average score, because there is an important frequency of products that do not reach a score of 1.

# %% [markdown]
# 2.- In the case of the reviews by the users is important that the manager of marketing and all their team, review what is happening with the quality of the product and even their packaging, to improve the score of review specially in the States with low score.

# %% [markdown]
# 3.- According the age, there is an excellent score by the group age of the users between 22 and 26 years old, specially in cities as New York, where is very important to be fashion. For this reason, the manager of distribution and sells could do a sourvey of which type of products could be implemented by this group age.

# %% [markdown]
# **Finally, this jupiter notebook was my first wonderfull experience learning this computer language program called Python. I am really happy with the results, although at the beginning I did not feel too much confident, it has not be too much easy specially by my background in statistics, but I am here showing that thanks at the teaching of our professors we can do great jobs!!**

# %% [markdown]
# For more information here is the link of the Jupiter Notebook from google drive:https://drive.google.com/file/d/18ZERrVT4rrHJwu0Zt0LWgM1SMnB_lj8R/view?usp=drive_link

# %% [markdown]
# Sonia Herrera Salgado
# Msc. Data Science for Business
